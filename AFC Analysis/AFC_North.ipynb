 1.0, 1.0, 0.9565217391304348, 1.0, 1.0, 1.0, 0.9565217391304348, 1.0, 1.0, 0.96, 0.9565217391304348, 0.8695652173913043, 0.8888888888888888, 1.0, 1.0, 1.0, 1.0, 0.9523809523809523, 0.9130434782608695, 1.0, 0.9523809523809523, 1.0, 1.0, 1.0, 0.9545454545454546, 0.9, 1.0, 0.8695652173913043, 1.0, 0.9411764705882353, 1.0, 0.9545454545454546, 1.0, 0.9565217391304348, 0.9090909090909091, 0.9130434782608695, 1.0, 1.0]

# %% [markdown]
# # Results

# %% [markdown]
# ### This Section shows the overall lexical diversity of the Baltimore Ravens, followed by the 100 most common words used in 50 of their latest tweets.¶

# %%
from collections import Counter

with open('Ravens_Large.pkl', 'rb') as f:
    tweets = pickle.load(f)
lexemes = []
for tweet in tweets:
    lexemes.extend(tweet.text.split())
#print(lexemes)
def lexical_diversity(tokens):
    return len(set(tokens)) / len(tokens)

print(lexical_diversity(lexemes))

common_words = Counter(lexemes)
print(common_words.most_common(100))
# Out:
# 0.6062550120288693
# [('the', 38), ('to', 33), ('a', 19), ('in', 17), ('is', 16), ('RT', 16), ('for', 15), ('on', 14), ('with', 13), ('and', 13), ('of', 12), ('work', 11), ('this', 11), ('be', 9), ('his', 9), ('at', 7), ('@Lj_era8', 7), ('#RavensFlock', 7), ('The', 6), ('📰:', 6), ('|', 6), ('have', 5), ('@ZEUS__78', 5), ('2019', 5), ('New', 5), ('We', 5), ('it', 5), ('year', 5), ('he', 5), ("he's", 5), ('😂', 5), ('about', 5), ('@_tonyjefferson', 5), ('‼️', 5), ('best', 4), ('schedule', 4), ('was', 4), ('us', 4), ('Draft', 4), ('@haydenrhurst', 4), ('our', 4), ('great', 4), ('from', 4), ('@MarkIngram22', 4), ('first', 4), ('NFL', 4), ('day', 4), ('I', 3), ('how', 3), ('Patrick', 3), ('Onwuasor', 3), ('Ravens', 3), ('This', 3), ('out', 3), ("We're", 3), ('you', 3), ('@nickboyle86', 3), ('get', 3), ('.@Lj_era8', 3), ('what', 3), ('has', 3), ('as', 3), ('"He\'s', 3), ("It's", 3), ('who', 3), ('@RGIII', 3), ('@Earl_Thomas', 3), ('😤', 3), ('@RGIII:', 3), ('@Ravens', 3), ('Marshal', 3), ('start', 2), ('#RavensMailbag', 2), ('Who', 2), ('here', 2), ('your', 2), ('their', 2), ('📰:…', 2), ('It', 2), ('an', 2), ('we’re', 2), ('@TwentyER:', 2), ('trying', 2), ('@Mandrews_81', 2), ('Join', 2), ("year's", 2), ('free', 2), ('fifth-annual', 2), ('L.I.F.T.', 2), ('empower', 2), ('next', 2), ('generation', 2), ('female', 2), ('entire', 2), ('"It\'s', 2), ('see', 2), ('guy', 2), ('like', 2), ('that', 2), ('Steve', 2)]

# %% [markdown]
# # RESULTS

# %% [markdown]
# ### This Section shows the overall lexical diversity of the Pittsburgh Steelers, followed by the 100 most common words used in 50 of their latest tweets.¶

# %%
from collections import Counter

with open('Steelers_Large.pkl', 'rb') as f:
    tweets = pickle.load(f)
lexemes = []
for tweet in tweets:
    lexemes.extend(tweet.text.split())
#print(lexemes)
def lexical_diversity(tokens):
    return len(set(tokens)) / len(tokens)

print(lexical_diversity(lexemes))

common_words = Counter(lexemes)
print(common_words.most_common(100))
# Out:
# 0.5529411764705883
# [('the', 59), ('to', 52), ('RT', 46), ('a', 23), ('your', 15), ('for', 15), ('in', 14), ('@Teresa_Varley:', 14), ('and', 13), ('|', 13), ('is', 12), ('of', 12), ('on', 11), ('We', 8), ('2019', 8), ('@steelers', 8), ('at', 8), ('have', 8), ('A', 8), ('@steelers:', 7), ('his', 7), ('about', 7), ('are', 7), ('my', 7), ('⠀', 7), ('chance', 7), ('you', 7), ('I', 6), ('@SteelersUnite:', 6), ('The', 6), ('@BobLabriola:', 6), ('as', 6), ('our', 6), ('win', 6), ('what', 5), ('get', 5), ('that', 5), ('it’s', 5), ('#Steelers', 5), ('it', 4), ('✅', 4), ("'I", 4), ('be', 4), ('down', 4), ('Get', 4), ('this', 4), ('@missi_matthews:', 4), ('back', 4), ('from', 4), ('love', 4), ('#HappyBirthday', 4), ('will', 4), ('work', 4), ('with', 4), ('Retweet', 4), ('Coach', 4), ('day', 3), ('am', 3), ('discusses', 3), ('NFL', 3), ('&amp;', 3), ('@CamHeyward', 3), ('having', 3), ('all', 3), ('us', 3), ('#HereWeGo', 3), ('draft', 3), ('can', 3), ('one', 3), ('before', 3), ('was', 3), ('start', 3), ('new', 3), ('In', 3), ('#BurghProud', 3), ('#tbt', 3), ('begins.', 3), ('do', 3), ('play', 3), ('#WildPlayWednesday', 3), ('#SteelersDraft', 3), ('signed', 3), ('Casey', 3), ('one-year', 3), ('@BordasLaw', 3), ('like', 3), ('it.', 3), ('pick', 3), ('is.', 2), ('Who?', 2), ('Where?', 2), ('When?', 2), ('🔜', 2), ('https://t.co/JQ6oSjEmQP', 2), ('It', 2), ('really', 2), ('think', 2), ('b…', 2), ('Draft', 2), ('Mike', 2)]

# %% [markdown]
# # RESULTS

# %% [markdown]
# ### This Section shows the overall lexical diversity of the Cleveland Browns, followed by the 100 most common words used in 50 of their latest tweets.¶

# %%
from collections import Counter

with open('Browns_Large.pkl', 'rb') as f:
    tweets = pickle.load(f)
lexemes = []
for tweet in tweets:
    lexemes.extend(tweet.text.split())
#print(lexemes)
def lexical_diversity(tokens):
    return len(set(tokens)) / len(tokens)

print(lexical_diversity(lexemes))

common_words = Counter(lexemes)
print(common_words.most_common(100))
# Out:
# 0.6068237205523964
# [('the', 33), ('to', 30), ('RT', 26), ('a', 22), ('is', 21), ('and', 17), ('of', 15), ('with', 13), ('Browns', 11), ('our', 10), ('you', 9), ('Cleveland', 9), ('on', 9), ('Happy', 8), ('Our', 8), ('@bakermayfield', 8), ('I', 7), ('was', 7), ('schedule', 7), ('Daily', 7), ('for', 7), ('this', 6), ('in', 6), ('The', 6), ('...', 5), ('We', 5), ('live!', 5), ('…', 5), ('🤔', 5), ('at', 5), ('time', 5), ('it', 5), ('»', 5), ('🎉', 5), ('more', 4), ('Building', 4), ('@obj', 4), ('-', 4), ('🏆', 4), ('how', 4), ('@BeauBishop', 4), ('@Browns_Daily', 4), ('your', 4), ('preseason', 4), ('as', 3), ('@joethomas73', 3), ('Two', 3), ("It's", 3), ('2019', 3), ('🧡', 3), ('set', 3), ('be', 3), ('WR', 3), ('us', 3), ('@Browns_Daily:', 3), ('live', 3), ('@NathanZegura:', 3), ('ICYMI:', 3), ('•', 3), ('Pro', 3), ('little', 3), ('This', 3), ('Draft', 3), ('Love', 3), ('having', 3), ('week', 3), ('set!', 3), ('one', 3), ('knew', 3), ('hours', 2), ('released', 2), ('👀', 2), ('until', 2), ('we', 2), ('🙌', 2), ('episode', 2), ('Kitchens', 2), ('b…', 2), ('iPhone', 2), ('X', 2), ('⬇️', 2), ('@NFL', 2), ('#WallpaperWednesday', 2), ('my', 2), ('today', 2), ('first', 2), ('Watch', 2), ('@Andrew_Gribble:', 2), ('an', 2), ('Film', 2), ('that’s', 2), ('not', 2), ('best', 2), ('what', 2), ('arrived', 2), ('from', 2), ('Huge', 2), ('@OKcleaner', 2), ('sure', 2), ('8', 2)]

# %% [markdown]
# # RESULTS

# %% [markdown]
# ### This Section shows the overall lexical diversity of the Cincinnati Bengals , followed by the 100 most common words used in 50 of their latest tweets.¶

# %%
from collections import Counter

with open('Bengals_Large.pkl', 'rb') as f:
    tweets = pickle.load(f)
lexemes = []
for tweet in tweets:
    lexemes.extend(tweet.text.split())
#print(lexemes)
def lexical_diversity(tokens):
    return len(set(tokens)) / len(tokens)

print(lexical_diversity(lexemes))

common_words = Counter(lexemes)
print(common_words.most_common(100))
# Out:
# 0.4938888888888889
# [('the', 90), ('#Bengals', 42), ('of', 32), ('in', 29), ('a', 28), ('to', 27), ('on', 22), ('and', 21), ('with', 16), ('The', 15), ('RT', 14), ('for', 14), ('at', 13), ('2019', 13), ('will', 11), ('be', 10), ('your', 9), ('📰:', 9), ('you', 8), ('first', 8), ('their', 8), ('#NewDEY', 8), ('@Bengals:', 7), ('top', 7), ('Taylor', 7), ('his', 7), ('Mock', 7), ('is', 6), ('media', 6), ('April', 6), ("It's", 6), ('time', 6), ("Hobson's", 6), ('Submit', 6), ('.@BengalsMarisa', 6), ('this', 6), ('NFL', 6), ('Zac', 6), ('Welcome', 6), ('In', 5), ('game', 5), ('as', 5), ('from', 5), ('our', 5), ('And', 5), ('prospects', 5), ('Draft.', 5), ('us', 5), ('Draft', 5), ('Bengals', 5), ('are', 5), ('he', 5), ('Media', 5), ('we', 4), ('look', 4), ('during', 4), ('NEWS:', 4), ('it’s', 4), ('Which', 4), ('think', 4), ('no', 4), ('question', 4), ('players', 4), ('another', 4), ('back', 4), ('head', 4), ('has', 4), ('A', 4), ('Forrest', 4), ('up', 4), ('Offseason', 4), ('As', 4), ('was', 4), ('one', 4), ('see', 4), ('one-year', 4), ('when', 4), ('position', 4), ('🎶', 4), ('What-If', 4), ('thinks', 4), ('–', 3), ('that', 3), ('schedule', 3), ('/', 3), ('\\', 3), ('new', 3), ('speaks', 3), ('play', 3), ('but', 3), ('do', 3), ('@BengalsMarisa:', 3), ('Mike', 3), ('should', 3), ('get', 3), ('Choice!', 3), ('it', 3), ('may', 3), ('answered', 3), ('weekly', 3)]

# %% [markdown]
# # RESULTS

# %% [markdown]
# ### This section does a sentiment analysis on 50 of the Baltimore Ravens most recent tweets.¶

# %%
import pickle
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

import nltk

from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

with open('Ravens_Large.pkl', 'rb') as f:
    chiefs = pickle.load(f)
    
def is_happy(tweet):
    score = analyzer.polarity_scores(tweet.text)
    return score['pos'] > 0.2

#happy_tweets = filter(is_happy, chiefs)
#for tweet in happy_tweets:
    #print(tweet.text)
    
def plottable_sentiments(tweets):
    texts = [tweet.text for tweet in tweets]
    sents = [analyzer.polarity_scores(t) for t in texts]
    pos_x = [s['pos'] for s in sents]
    neu_y = [s['neu'] for s in sents]
    neg_z = [s['neg'] for s in sents]
    return pos_x, neu_y, neg_z
    
chiefs_texts = []
for tweet in chiefs:
    chiefs_texts.append(tweet.text)
    
chiefs_texts = [tweet.text for tweet in chiefs]
chiefs_sentiments = [analyzer.polarity_scores(t) for t in chiefs_texts]
#print(chiefs_sentiments)
    
# To plot 3d scatter plot
# We need 3 lists: x vals, y vals, z vals
pos_x = [sent['pos'] for sent in chiefs_sentiments]
neu_y = [sent['neu'] for sent in chiefs_sentiments]
neg_z = [sent['neg'] for sent in chiefs_sentiments]
# boilerplate
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
rbx, rby, rbz = plottable_sentiments(chiefs)

with open('Ravens_Large.pkl', 'rb') as f:
    chiefs_tweets = pickle.load(f)
    
qx, qy, qz = plottable_sentiments(chiefs_tweets)

ax.scatter(rbx, rby, rbz, c='r', marker='o')
ax.scatter(qx, qy, qz, c = 'purple', marker='^')
ax.set_xlabel('Positive')
ax.set_ylabel('Neutral')
ax.set_zlabel('Negative')
plt.show()

# %% [markdown]
# # RESULTS

# %% [markdown]
# ### This section does a sentiment analysis on 50 of the Pittsburgh Steelers most recent tweets.¶

# %%
import pickle
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

import nltk

from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

with open('Steelers_Large.pkl', 'rb') as f:
    chiefs = pickle.load(f)
    
def is_happy(tweet):
    score = analyzer.polarity_scores(tweet.text)
    return score['pos'] > 0.2

#happy_tweets = filter(is_happy, chiefs)
#for tweet in happy_tweets:
    #print(tweet.text)
    
def plottable_sentiments(tweets):
    texts = [tweet.text for tweet in tweets]
    sents = [analyzer.polarity_scores(t) for t in texts]
    pos_x = [s['pos'] for s in sents]
    neu_y = [s['neu'] for s in sents]
    neg_z = [s['neg'] for s in sents]
    return pos_x, neu_y, neg_z
    
chiefs_texts = []
for tweet in chiefs:
    chiefs_texts.append(tweet.text)
    
chiefs_texts = [tweet.text for tweet in chiefs]
chiefs_sentiments = [analyzer.polarity_scores(t) for t in chiefs_texts]
#print(chiefs_sentiments)
    
# To plot 3d scatter plot
# We need 3 lists: x vals, y vals, z vals
pos_x = [sent['pos'] for sent in chiefs_sentiments]
neu_y = [sent['neu'] for sent in chiefs_sentiments]
neg_z = [sent['neg'] for sent in chiefs_sentiments]
# boilerplate
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
rbx, rby, rbz = plottable_sentiments(chiefs)

with open('Steelers_Large.pkl', 'rb') as f:
    chiefs_tweets = pickle.load(f)
    
qx, qy, qz = plottable_sentiments(chiefs_tweets)

ax.scatter(rbx, rby, rbz, c='r', marker='o')
ax.scatter(qx, qy, qz, c = 'purple', marker='^')
ax.set_xlabel('Positive')
ax.set_ylabel('Neutral')
ax.set_zlabel('Negative')
plt.show()

# %% [markdown]
# # RESULTS

# %% [markdown]
# ### This section does a sentiment analysis on 50 of the Cleveland Browns most recent tweets.¶

# %%
import pickle
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

import nltk

from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

with open('Browns_Large.pkl', 'rb') as f:
    chiefs = pickle.load(f)
    
def is_happy(tweet):
    score = analyzer.polarity_scores(tweet.text)
    return score['pos'] > 0.2

#happy_tweets = filter(is_happy, chiefs)
#for tweet in happy_tweets:
    #print(tweet.text)
    
def plottable_sentiments(tweets):
    texts = [tweet.text for tweet in tweets]
    sents = [analyzer.polarity_scores(t) for t in texts]
    pos_x = [s['pos'] for s in sents]
    neu_y = [s['neu'] for s in sents]
    neg_z = [s['neg'] for s in sents]
    return pos_x, neu_y, neg_z
    
chiefs_texts = []
for tweet in chiefs:
    chiefs_texts.append(tweet.text)
    
chiefs_texts = [tweet.text for tweet in chiefs]
chiefs_sentiments = [analyzer.polarity_scores(t) for t in chiefs_texts]
#print(chiefs_sentiments)
    
# To plot 3d scatter plot
# We need 3 lists: x vals, y vals, z vals
pos_x = [sent['pos'] for sent in chiefs_sentiments]
neu_y = [sent['neu'] for sent in chiefs_sentiments]
neg_z = [sent['neg'] for sent in chiefs_sentiments]
# boilerplate
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
rbx, rby, rbz = plottable_sentiments(chiefs)

with open('Browns_Large.pkl', 'rb') as f:
    chiefs_tweets = pickle.load(f)
    
qx, qy, qz = plottable_sentiments(chiefs_tweets)

ax.scatter(rbx, rby, rbz, c='r', marker='o')
ax.scatter(qx, qy, qz, c = 'purple', marker='^')
ax.set_xlabel('Positive')
ax.set_ylabel('Neutral')
ax.set_zlabel('Negative')
plt.show()

# %% [markdown]
# # RESULTS

# %% [markdown]
# ### This section does a sentiment analysis on 50 of the Cincinnati Bengals most recent tweets.¶

# %%
import pickle
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

import nltk

from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

with open('Bengals_Large.pkl', 'rb') as f:
    chiefs = pickle.load(f)
    
def is_happy(tweet):
    score = analyzer.polarity_scores(tweet.text)
    return score['pos'] > 0.2

#happy_tweets = filter(is_happy, chiefs)
#for tweet in happy_tweets:
    #print(tweet.text)
    
def plottable_sentiments(tweets):
    texts = [tweet.text for tweet in tweets]
    sents = [analyzer.polarity_scores(t) for t in texts]
    pos_x = [s['pos'] for s in sents]
    neu_y = [s['neu'] for s in sents]
    neg_z = [s['neg'] for s in sents]
    return pos_x, neu_y, neg_z
    
chiefs_texts = []
for tweet in chiefs:
    chiefs_texts.append(tweet.text)
    
chiefs_texts = [tweet.text for tweet in chiefs]
chiefs_sentiments = [analyzer.polarity_scores(t) for t in chiefs_texts]
#print(chiefs_sentiments)
    
# To plot 3d scatter plot
# We need 3 lists: x vals, y vals, z vals
pos_x = [sent['pos'] for sent in chiefs_sentiments]
neu_y = [sent['neu'] for sent in chiefs_sentiments]
neg_z = [sent['neg'] for sent in chiefs_sentiments]
# boilerplate
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
rbx, rby, rbz = plottable_sentiments(chiefs)

with open('Bengals_Large.pkl', 'rb') as f:
    chiefs_tweets = pickle.load(f)
    
qx, qy, qz = plottable_sentiments(chiefs_tweets)

ax.scatter(rbx, rby, rbz, c='r', marker='o')
ax.scatter(qx, qy, qz, c = 'purple', marker='^')
ax.set_xlabel('Positive')
ax.set_ylabel('Neutral')
ax.set_zlabel('Negative')
plt.show()

# %% [markdown]
# # RESULTS

# %% [markdown]
# ### This section displays user data from the Baltimore Ravens account. Information included is Twitter handle, description, followers, following, & URL.

# %%
from twitter_keys import consumer_key, consumer_secret, access_token, access_secret
import tweepy

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth)

import pickle

user = api.get_user('Ravens')

with open('Ravens_Info.pkl', 'wb') as f:
   pickle.dump(user, f)

# %%
import pickle

with open('Ravens_Info.pkl', 'rb') as f:
          user = pickle.load(f)
print (user.screen_name)
print (user.description)
print (user.followers_count)
print (user.statuses_count)
print (user.url)
# Out:
# Ravens
# Official Twitter account of the Baltimore Ravens | Instagram: Ravens | 👻: BLTRavens | @RavensPromos | @RavensCommunity | #RavensFlock
# 1456372
# 66068
# https://t.co/k5Fk8jSTPZ

# %% [markdown]
# # RESULTS

# %% [markdown]
# ### This section displays user data from the Pittsburgh Steelers account. Information included is Twitter handle, description, followers, following, & URL.

# %%
from twitter_keys import consumer_key, consumer_secret, access_token, access_secret
import tweepy

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth)

import pickle

user = api.get_user('steelers')

with open('Steelers_Info.pkl', 'wb') as f:
   pickle.dump(user, f)

# %%
import pickle

with open('Steelers_Info.pkl', 'rb') as f:
          user = pickle.load(f)
print (user.screen_name)
print (user.description)
print (user.followers_count)
print (user.statuses_count)
print (user.url)
# Out:
# steelers
# World Champions: IX, X, XIII, XIV, XL, XLIII
# 3423627
# 43451
# https://t.co/xpaPQGD2vo

# %% [markdown]
# # RESULTS

# %% [markdown]
# ### This section displays user data from the Cleveland Browns account. Information included is Twitter handle, description, followers, following, & URL.

# %%
from twitter_keys import consumer_key, consumer_secret, access_token, access_secret
import tweepy

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth)

import pickle

user = api.get_user('Browns')

with open('Browns_Info.pkl', 'wb') as f:
   pickle.dump(user, f)

# %%
import pickle

with open('Browns_Info.pkl', 'rb') as f:
          user = pickle.load(f)
print (user.screen_name)
print (user.description)
print (user.followers_count)
print (user.statuses_count)
print (user.url)
# Out:
# Browns
# 🐶
# 1199397
# 42086
# https://t.co/UvFR5CfMf6

# %% [markdown]
# # RESULTS

# %% [markdown]
# ### This section displays user data from the Cincinnati Bengals account. Information included is Twitter handle, description, followers, following, & URL.

# %%
from twitter_keys import consumer_key, consumer_secret, access_token, access_secret
import tweepy

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth)

import pickle

user = api.get_user('Bengals')

with open('Bengals_Info.pkl', 'wb') as f:
   pickle.dump(user, f)

# %%
import pickle

with open('Bengals_Info.pkl', 'rb') as f:
          user = pickle.load(f)
print (user.screen_name)
print (user.description)
print (user.followers_count)
print (user.statuses_count)
print (user.url)
# Out:
# Bengals
# Official Twitter account of the Cincinnati Bengals. WHO DEY! For Tickets: Local (513) 621-8383 or Toll Free (866) 621-8383 or https://t.co/lexPOVcvFI.
# 828050
# 22462
# https://t.co/wXeji9Zia6

# %% [markdown]
# # RESULTS
