Large.pkl', 'rb') as f:
    tweets = pickle.load(f)
lexemes = []
for tweet in tweets:
    lexemes.extend(tweet.text.split())
#print(lexemes)
def lexical_diversity(tokens):
    return len(set(tokens)) / len(tokens)

print(lexical_diversity(lexemes))

common_words = Counter(lexemes)
print(common_words.most_common(100))
# Out:
# 0.5788061703554661
# [('the', 61), ('to', 40), ('in', 31), ('of', 26), ('RT', 20), ('a', 19), ('and', 17), ('on', 16), ('is', 15), ('#ChiefsKingdom', 12), ('have', 11), ('for', 11), ('The', 10), ('with', 10), ('We', 9), ('at', 9), ('that', 8), ('our', 8), ('be', 8), ('we', 8), ('his', 7), ('are', 7), ('⠀', 7), ('2019', 6), ('#Chiefs', 6), ('will', 6), ('as', 6), ('schedule', 5), ('@ChiefsReporter', 5), ('🙌', 5), ('@ArrowheadEvents:', 5), ('what', 5), ('@KCChiefs_Matt:', 5), ('has', 5), ('was', 5), ('an', 5), ('get', 5), ('“We', 5), ('who', 5), ('NFL', 4), ('@ChiefsReporter:', 4), ('up', 4), ('I', 4), ('first', 4), ('from', 4), ('👏', 4), ('all', 4), ('here', 4), ('back', 4), ('about', 4), ('your', 4), ('this', 4), ('games', 3), ('selected', 3), ('With', 3), ('draft', 3), ('City', 3), ('Monday', 3), ('time', 3), ('us', 3), ('you', 3), ('@EmanOgbah', 3), ('today', 3), ('#NFLDraft', 3), ('last', 3), ('guys', 3), ('ready', 3), ('take', 3), ('day', 3), ('💪', 3), ('-', 3), ('happy', 3), ('look', 3), ('like', 3), ('birthday!', 3), ('Patrick', 3), ('Top', 3), ('Photo', 3), ('It', 3), ('x', 3), ('signed', 3), ('free', 3), ('agent', 3), ('Arrowhead', 3), ('history', 3), ('new', 3), ('Travis', 3), ('Kelce', 3), ('3', 2), ('Pro', 2), ('Walter', 2), ('the…', 2), ('most', 2), ('3rd', 2), ('next', 2), ('some', 2), ('newest', 2), ('their', 2), ('time.', 2), ('shares', 2)]

# %% [markdown]
# # RESULTS

# %% [markdown]
# ### This Section shows the overall lexical diversity of the Oakland Raiders, followed by the 100 most common words used in 50 of their latest tweets

# %%
from collections import Counter

with open('Raiders_Large.pkl', 'rb') as f:
    tweets = pickle.load(f)
lexemes = []
for tweet in tweets:
    lexemes.extend(tweet.text.split())
#print(lexemes)
def lexical_diversity(tokens):
    return len(set(tokens)) / len(tokens)

print(lexical_diversity(lexemes))

common_words = Counter(lexemes)
print(common_words.most_common(100))
# Out:
# 0.6062452399086062
# [('to', 39), ('#RaiderNation', 29), ('RT', 28), ('the', 28), ('and', 22), ('a', 18), ('have', 17), ('in', 16), ('We', 16), ('of', 15), ('for', 14), ('🎂', 13), ('The', 11), ('signed', 9), ('is', 8), ('get', 8), ('that', 8), ('our', 7), ('Mike', 7), ('this', 6), ('you', 6), ('back', 6), ('has', 6), ('Happy', 6), ('at', 5), ('»', 5), ('with', 5), ('on', 5), ('up', 5), ('GM', 5), ('Mayock', 5), ('first', 4), ('@Raiders', 4), ('guys', 4), ('his', 4), ('No.', 4), ('every', 4), ('@derekcarrqb', 4), ('One', 3), ('@NFLUK:', 3), ('Welcome', 3), ('|', 3), ('@Big_Tah47:', 3), ('out', 3), ('back.', 3), ('re-signed', 3), ('are', 3), ('can', 3), ('from', 3), ('I', 3), ('WR', 3), ('"You', 3), ('knows', 3), ('some', 3), ('him', 3), ('football', 3), ('there', 3), ('Raiders', 3), ('bday', 3), ('@BMarshh', 3), ('✔️', 3), ('A', 2), ('@Raiders:', 2), ('Pride', 2), ('poise.', 2), ('Phase', 2), ('heating', 2), ('up.', 2), ('https://t.co/cbmHfiTiAi', 2), ('game', 2), ('@SpursOfficial', 2), ('🔥', 2), ('if', 2), ('You', 2), ('know', 2), ('close', 2), ('DE', 2), ('work.', 2), ('into', 2), ('like', 2), ("We're", 2), ('More', 2), ('Not', 2), ('along', 2), ("Let's", 2), ('it.', 2), ('their', 2), ('//', 2), ('@SJSUSpartanFB:', 2), ('local', 2), ('RB', 2), ('as', 2), ('want', 2), ('love', 2), ('Coach', 2), ('got', 2), ('ready', 2), ('@derekcarrqb:', 2), ("it's", 2), ('about', 2)]

# %% [markdown]
# # RESULTS

# %% [markdown]
# ### This Section shows the overall lexical diversity of the Los Angeles Chargers, followed by the 100 most common words used in 50 of their latest tweets

# %%
from collections import Counter

with open('Chargers_Large.pkl', 'rb') as f:
    tweets = pickle.load(f)
lexemes = []
for tweet in tweets:
    lexemes.extend(tweet.text.split())
#print(lexemes)
def lexical_diversity(tokens):
    return len(set(tokens)) / len(tokens)

print(lexical_diversity(lexemes))

common_words = Counter(lexemes)
print(common_words.most_common(100))
# Out:
# 0.675392670157068
# [('the', 21), ('RT', 13), ('a', 11), ('to', 11), ('|', 10), ('our', 8), ('it', 8), ('in', 7), ('»', 7), ('you', 7), ('@Chargers:', 6), ('and', 5), ('this', 5), ('x', 5), ('of', 5), ('I', 5), ('for', 4), ('who', 4), ('out', 4), ('👀', 4), ('powder', 4), ('🙌', 4), ('@DerekWatt34', 4), ('→', 4), ('@DerwinJames', 4), ('on', 4), ('be', 4), ('can', 4), ('that', 4), ('@jbbigbear', 4), ('🚨', 4), ('one', 3), ('week', 3), ('@Keenan13Allen:', 3), ('2019', 3), ('at', 3), ('think', 3), ('tell', 3), ('see', 3), ('has', 3), ('is', 3), ('Coach', 3), ('back', 3), ('miss', 3), ('go', 3), ('@Melvingordon25', 3), ('more', 3), ('@NFL', 2), ('those', 2), ('@ChargersCR', 2), ('We', 2), ('tho', 2), ('#WallpaperWednesday', 2), ('schedule', 2), ('😤', 2), ('😂', 2), ("you're", 2), ('welcome.', 2), ('https://t.co/CSLCALd289', 2), ('first', 2), ('en', 2), ('el', 2), ('Night.', 2), ('but', 2), ('really', 2), ('#BoltUp', 2), ('old', 2), ('WE', 2), ('BACK.', 2), ('https://t.co/IXxsybuWc4', 2), ('working', 2), ('message', 2), ('work,', 2), ('work.', 2), ('Bolt', 2), ('Fam.', 2), ('signed', 2), ('his', 2), ('got?', 2), ('#GameofThrones', 2), ('https://t.co/BIbZwDhvf5', 2), ('with', 2), ('🥳', 2), ('man', 2), ('people', 2), ('NEW', 2), ('like', 2), ('their', 2), ('we', 2), ('🤷\u200d♂️', 2), ('#TBT', 2), ('https://t.co/8pY5TBAhVP', 2), ('name', 2), ('iconic', 2), ('duo,', 2), ("we'll", 2), ('wait.', 2), ('https://t.co/IfbgXUHhLU', 2), ('two', 2), ("We've", 2)]

# %% [markdown]
# # RESULTS

# %% [markdown]
# ### This Section shows the overall lexical diversity of the Denver Broncos, followed by the 100 most common words used in 50 of their latest tweets

# %%
from collections import Counter

with open('Broncos_Large.pkl', 'rb') as f:
    tweets = pickle.load(f)
lexemes = []
for tweet in tweets:
    lexemes.extend(tweet.text.split())
#print(lexemes)
def lexical_diversity(tokens):
    return len(set(tokens)) / len(tokens)

print(lexical_diversity(lexemes))

common_words = Counter(lexemes)
print(common_words.most_common(100))
# Out:
# 0.5677374301675978
# [('the', 57), ('of', 36), ('RT', 34), ('to', 34), ('in', 20), ('@BroncosOffField:', 19), ('a', 19), ('our', 13), ('on', 12), ('for', 11), ('and', 11), ('you', 10), ('#BroncosCountry', 9), ('this', 9), ('will', 9), ('with', 9), ('your', 9), ('be', 8), ('that', 8), ('are', 8), ('LIVE:', 6), ('meets', 6), ('media', 6), ('Day', 6), ('2019', 6), ('#BroncosDraft', 6), ('»', 6), ('—', 6), ('&amp;', 6), ('@Broncos', 6), ('we', 6), ('@VonMiller', 5), ('at', 5), ('📰', 5), ('#Broncos', 5), ('is', 5), ('join', 5), ('best', 5), ('us', 5), ('after', 4), ('voluntary', 4), ('veteran', 4), ('minicamp', 4), ('schedule', 4), ("it's", 4), ('it', 4), ('Our', 4), ('#BeAChampion', 4), ('-', 4), ('#NFLDraft', 4), ('preseason', 4), ('their', 4), ("Can't", 3), ('wait', 3), ('Get', 3), ('draft', 3), ('know', 3), ('first', 3), ('got', 3), ('😤', 3), ('And', 3), ('my', 3), ('how', 3), ('good', 3), ('Good', 3), ('those', 3), ('I', 3), ('Denver', 3), ('...', 3), ('🔸', 3), ('A', 3), ('Master', 3), ('coming', 3), ('was', 3), ('one', 3), ('@BroncosCheer:', 3), ('miss', 3), ('opportunity', 3), ('always', 3), ('🙌', 3), ('so', 3), ('out', 3), ('June', 3), ('#BroncosCountry,', 3), ('The', 3), ('2', 2), ('@Broncos:', 2), ('@Chargers', 2), ('@ChicagoBears', 2), ('🍊👊', 2), ('https://t.co/WDqXwUhg3T', 2), ('#NFLDraft?', 2), ('sneak', 2), ('peek', 2), ('War', 2), ('Room', 2), ('meet', 2), ('first-round', 2), ('pic…', 2), ("We'll", 2)]

# %% [markdown]
# # RESULTS

# %% [markdown]
# ### This section does a sentiment analysis on 50 of the Kansas City Chiefs most recent tweets

# %%
import pickle
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

import nltk

from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

with open('Chiefs_Large.pkl', 'rb') as f:
    chiefs = pickle.load(f)
    
def is_happy(tweet):
    score = analyzer.polarity_scores(tweet.text)
    return score['pos'] > 0.2

#happy_tweets = filter(is_happy, chiefs)
#for tweet in happy_tweets:
    #print(tweet.text)
    
def plottable_sentiments(tweets):
    texts = [tweet.text for tweet in tweets]
    sents = [analyzer.polarity_scores(t) for t in texts]
    pos_x = [s['pos'] for s in sents]
    neu_y = [s['neu'] for s in sents]
    neg_z = [s['neg'] for s in sents]
    return pos_x, neu_y, neg_z
    
chiefs_texts = []
for tweet in chiefs:
    chiefs_texts.append(tweet.text)
    
chiefs_texts = [tweet.text for tweet in chiefs]
chiefs_sentiments = [analyzer.polarity_scores(t) for t in chiefs_texts]
#print(chiefs_sentiments)
    
# To plot 3d scatter plot
# We need 3 lists: x vals, y vals, z vals
pos_x = [sent['pos'] for sent in chiefs_sentiments]
neu_y = [sent['neu'] for sent in chiefs_sentiments]
neg_z = [sent['neg'] for sent in chiefs_sentiments]
# boilerplate
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
rbx, rby, rbz = plottable_sentiments(chiefs)

with open('Chiefs_Large.pkl', 'rb') as f:
    chiefs_tweets = pickle.load(f)
    
qx, qy, qz = plottable_sentiments(chiefs_tweets)

ax.scatter(rbx, rby, rbz, c='r', marker='o')
ax.scatter(qx, qy, qz, c = 'purple', marker='^')
ax.set_xlabel('Positive')
ax.set_ylabel('Neutral')
ax.set_zlabel('Negative')
plt.show()

# %% [markdown]
# # RESULTS

# %% [markdown]
# ### This section does a sentiment analysis on 50 of the Oakland Raiders most recent tweets

# %%
import pickle
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

import nltk

from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

with open('Raiders_Large.pkl', 'rb') as f:
    chiefs = pickle.load(f)
    
def is_happy(tweet):
    score = analyzer.polarity_scores(tweet.text)
    return score['pos'] > 0.2

#happy_tweets = filter(is_happy, chiefs)
#for tweet in happy_tweets:
    #print(tweet.text)
    
def plottable_sentiments(tweets):
    texts = [tweet.text for tweet in tweets]
    sents = [analyzer.polarity_scores(t) for t in texts]
    pos_x = [s['pos'] for s in sents]
    neu_y = [s['neu'] for s in sents]
    neg_z = [s['neg'] for s in sents]
    return pos_x, neu_y, neg_z
    
chiefs_texts = []
for tweet in chiefs:
    chiefs_texts.append(tweet.text)
    
chiefs_texts = [tweet.text for tweet in chiefs]
chiefs_sentiments = [analyzer.polarity_scores(t) for t in chiefs_texts]
#print(chiefs_sentiments)
    
# To plot 3d scatter plot
# We need 3 lists: x vals, y vals, z vals
pos_x = [sent['pos'] for sent in chiefs_sentiments]
neu_y = [sent['neu'] for sent in chiefs_sentiments]
neg_z = [sent['neg'] for sent in chiefs_sentiments]
# boilerplate
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
rbx, rby, rbz = plottable_sentiments(chiefs)

with open('Raiders_Large.pkl', 'rb') as f:
    chiefs_tweets = pickle.load(f)
    
qx, qy, qz = plottable_sentiments(chiefs_tweets)

ax.scatter(rbx, rby, rbz, c='r', marker='o')
ax.scatter(qx, qy, qz, c = 'purple', marker='^')
ax.set_xlabel('Positive')
ax.set_ylabel('Neutral')
ax.set_zlabel('Negative')
plt.show()

# %% [markdown]
# # RESULTS

# %% [markdown]
# ### This section does a sentiment analysis on 50 of the Los Angeles Chargers most recent tweets

# %%
import pickle
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

import nltk

from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

with open('Chargers_Large.pkl', 'rb') as f:
    chiefs = pickle.load(f)
    
def is_happy(tweet):
    score = analyzer.polarity_scores(tweet.text)
    return score['pos'] > 0.2

#happy_tweets = filter(is_happy, chiefs)
#for tweet in happy_tweets:
    #print(tweet.text)
    
def plottable_sentiments(tweets):
    texts = [tweet.text for tweet in tweets]
    sents = [analyzer.polarity_scores(t) for t in texts]
    pos_x = [s['pos'] for s in sents]
    neu_y = [s['neu'] for s in sents]
    neg_z = [s['neg'] for s in sents]
    return pos_x, neu_y, neg_z
    
chiefs_texts = []
for tweet in chiefs:
    chiefs_texts.append(tweet.text)
    
chiefs_texts = [tweet.text for tweet in chiefs]
chiefs_sentiments = [analyzer.polarity_scores(t) for t in chiefs_texts]
#print(chiefs_sentiments)
    
# To plot 3d scatter plot
# We need 3 lists: x vals, y vals, z vals
pos_x = [sent['pos'] for sent in chiefs_sentiments]
neu_y = [sent['neu'] for sent in chiefs_sentiments]
neg_z = [sent['neg'] for sent in chiefs_sentiments]
# boilerplate
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
rbx, rby, rbz = plottable_sentiments(chiefs)

with open('Chargers_Large.pkl', 'rb') as f:
    chiefs_tweets = pickle.load(f)
    
qx, qy, qz = plottable_sentiments(chiefs_tweets)

ax.scatter(rbx, rby, rbz, c='r', marker='o')
ax.scatter(qx, qy, qz, c = 'purple', marker='^')
ax.set_xlabel('Positive')
ax.set_ylabel('Neutral')
ax.set_zlabel('Negative')
plt.show()

# %% [markdown]
# # RESULTS

# %% [markdown]
# ### This section does a sentiment analysis on 50 of the Denver Broncos most recent tweets

# %%
import pickle
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

import nltk

from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

with open('Broncos_Large.pkl', 'rb') as f:
    chiefs = pickle.load(f)
    
def is_happy(tweet):
    score = analyzer.polarity_scores(tweet.text)
    return score['pos'] > 0.2

#happy_tweets = filter(is_happy, chiefs)
#for tweet in happy_tweets:
    #print(tweet.text)
    
def plottable_sentiments(tweets):
    texts = [tweet.text for tweet in tweets]
    sents = [analyzer.polarity_scores(t) for t in texts]
    pos_x = [s['pos'] for s in sents]
    neu_y = [s['neu'] for s in sents]
    neg_z = [s['neg'] for s in sents]
    return pos_x, neu_y, neg_z
    
chiefs_texts = []
for tweet in chiefs:
    chiefs_texts.append(tweet.text)
    
chiefs_texts = [tweet.text for tweet in chiefs]
chiefs_sentiments = [analyzer.polarity_scores(t) for t in chiefs_texts]
#print(chiefs_sentiments)
    
# To plot 3d scatter plot
# We need 3 lists: x vals, y vals, z vals
pos_x = [sent['pos'] for sent in chiefs_sentiments]
neu_y = [sent['neu'] for sent in chiefs_sentiments]
neg_z = [sent['neg'] for sent in chiefs_sentiments]
# boilerplate
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
rbx, rby, rbz = plottable_sentiments(chiefs)

with open('Broncos_Large.pkl', 'rb') as f:
    chiefs_tweets = pickle.load(f)
    
qx, qy, qz = plottable_sentiments(chiefs_tweets)

ax.scatter(rbx, rby, rbz, c='r', marker='o')
ax.scatter(qx, qy, qz, c = 'purple', marker='^')
ax.set_xlabel('Positive')
ax.set_ylabel('Neutral')
ax.set_zlabel('Negative')
plt.show()

# %% [markdown]
# # RESULTS

# %% [markdown]
# ### This section displays user data from the Kansas City Chiefs account. Information included is Twitter handle, description, followers, following, & URL.

# %%
#from twitter_keys import consumer_key, consumer_secret, access_token, access_secret
#import tweepy

#auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
#auth.set_access_token(access_token, access_secret)

#api = tweepy.API(auth)

#import pickle

#user = api.get_user('Patriots')

#with open('Patriots_Info.pkl', 'wb') as f:
#   pickle.dump(user, f)

# %%
import pickle

with open('Chiefs_Info.pkl', 'rb') as f:
          user = pickle.load(f)
print (user.screen_name)
print (user.description)
print (user.followers_count)
print (user.statuses_count)
print (user.url)
# Out:
# Chiefs
# Official Twitter account of the Kansas City #Chiefs. | #ChiefsKingdom
# 1271972
# 38142
# https://t.co/K7Q25DNqzQ

# %% [markdown]
# # RESULTS

# %% [markdown]
# ### This section displays user data from the Oakland Raiders account. Information included is Twitter handle, description, followers, following, & URL.

# %%
#from twitter_keys import consumer_key, consumer_secret, access_token, access_secret
#import tweepy

#auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
#auth.set_access_token(access_token, access_secret)

#api = tweepy.API(auth)

#import pickle

#user = api.get_user('MiamiDolphins')

#with open('Dolphins_Info.pkl', 'wb') as f:
#   pickle.dump(user, f)

# %%
import pickle

with open('Raiders_Info.pkl', 'rb') as f:
          user = pickle.load(f)
print (user.screen_name)
print (user.description)
print (user.followers_count)
print (user.statuses_count)
print (user.url)
# Out:
# Raiders
# The official account of the three-time Super Bowl champion Oakland Raiders
# 1597856
# 52431
# https://t.co/YFNjoQLkl4

# %% [markdown]
# # RESULTS

# %% [markdown]
# ### This section displays user data from the Los Angeles Chargers account. Information included is Twitter handle, description, followers, following, & URL.

# %%
#from twitter_keys import consumer_key, consumer_secret, access_token, access_secret
#import tweepy

#auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
#auth.set_access_token(access_token, access_secret)

#api = tweepy.API(auth)

#import pickle

#user = api.get_user('buffalobills')

#with open('Bills_Info.pkl', 'wb') as f:
#   pickle.dump(user, f)

# %%
import pickle

with open('Chargers_Info.pkl', 'rb') as f:
          user = pickle.load(f)
print (user.screen_name)
print (user.description)
print (user.followers_count)
print (user.statuses_count)
print (user.url)
# Out:
# Chargers
# #FightForEachOther ⚡️
# 836092
# 48695
# https://t.co/m37EOVFzAv

# %% [markdown]
# # RESULTS

# %% [markdown]
# ### This section displays user data from the Denver Broncos account. Information included is Twitter handle, description, followers, following, & URL.

# %%
#from twitter_keys import consumer_key, consumer_secret, access_token, access_secret
#import tweepy

#auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
#auth.set_access_token(access_token, access_secret)

#api = tweepy.API(auth)

#import pickle

#user = api.get_user('nyjets')

#with open('Jets_Info.pkl', 'wb') as f:
#   pickle.dump(user, f)

# %%
import pickle

with open('Broncos_Info.pkl', 'rb') as f:
          user = pickle.load(f)
print (user.screen_name)
print (user.description)
print (user.followers_count)
print (user.statuses_count)
print (user.url)
# Out:
# Broncos
# Twitter home of the three-time Super Bowl champions: XXXII, XXXIII and #SB50
# 2637652
# 53678
# https://t.co/kMJsYCJRIE
