# %% [markdown]
# # INSERT TEXT

# %%
from twitter_keys import consumer_key, consumer_secret, access_token, access_secret
import tweepy

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth)

import pickle

public_tweets = api.user_timeline('Patriots', count=100)

with open('Patriots_Large.pkl', 'wb') as f:
   pickle.dump(public_tweets, f)

public_tweets = api.user_timeline('MiamiDolphins', count=100)

with open('Dolphins_Large.pkl', 'wb') as f:
   pickle.dump(public_tweets, f)

public_tweets = api.user_timeline('buffalobills', count=100)

with open('Bills_Large.pkl', 'wb') as f:
   pickle.dump(public_tweets, f)

public_tweets = api.user_timeline('nyjets', count=100)

with open('Jets_Large.pkl', 'wb') as f:
   pickle.dump(public_tweets, f)
public_tweets = api.user_timeline('Ravens', count=100)

with open('Ravens_Large.pkl', 'wb') as f:
   pickle.dump(public_tweets, f)

public_tweets = api.user_timeline('steelers', count=100)

with open('Steelers_Large.pkl', 'wb') as f:
   pickle.dump(public_tweets, f)

public_tweets = api.user_timeline('Browns', count=100)

with open('Browns_Large.pkl', 'wb') as f:
   pickle.dump(public_tweets, f)

public_tweets = api.user_timeline('Bengals', count=100)

with open('Bengals_Large.pkl', 'wb') as f:
   pickle.dump(public_tweets, f)
public_tweets = api.user_timeline('HoustonTexans', count=100)

with open('Texans_Large.pkl', 'wb') as f:
   pickle.dump(public_tweets, f)

public_tweets = api.user_timeline('Colts', count=100)

with open('Colts_Large.pkl', 'wb') as f:
   pickle.dump(public_tweets, f)

public_tweets = api.user_timeline('Titans', count=100)

with open('Titans_Large.pkl', 'wb') as f:
   pickle.dump(public_tweets, f)

public_tweets = api.user_timeline('Jaguars', count=100)

with open('Jaguars_Large.pkl', 'wb') as f:
   pickle.dump(public_tweets, f)
public_tweets = api.user_timeline('Chiefs', count=100)

with open('Chiefs_Large.pkl', 'wb') as f:
   pickle.dump(public_tweets, f)

public_tweets = api.user_timeline('Raiders', count=100)

with open('Raiders_Large.pkl', 'wb') as f:
   pickle.dump(public_tweets, f)

public_tweets = api.user_timeline('Chargers', count=100)

with open('Chargers_Large.pkl', 'wb') as f:
   pickle.dump(public_tweets, f)

public_tweets = api.user_timeline('Broncos', count=100)

with open('Broncos_Large.pkl', 'wb') as f:
   pickle.dump(public_tweets, f)
public_tweets = api.user_timeline('dallascowboys', count=100)

with open('Cowboys_Large.pkl', 'wb') as f:
   pickle.dump(public_tweets, f)

public_tweets = api.user_timeline('Eagles', count=100)

with open('Eagles_Large.pkl', 'wb') as f:
   pickle.dump(public_tweets, f)

public_tweets = api.user_timeline('Redskins', count=100)

with open('Redskins_Large.pkl', 'wb') as f:
   pickle.dump(public_tweets, f)

public_tweets = api.user_timeline('Giants', count=100)

with open('Giants_Large.pkl', 'wb') as f:
   pickle.dump(public_tweets, f)
public_tweets = api.user_timeline('ChicagoBears', count=100)

with open('Bears_Large.pkl', 'wb') as f:
   pickle.dump(public_tweets, f)

public_tweets = api.user_timeline('Vikings', count=100)

with open('Vikings_Large.pkl', 'wb') as f:
   pickle.dump(public_tweets, f)

public_tweets = api.user_timeline('packers', count=100)

with open('Packers_Large.pkl', 'wb') as f:
   pickle.dump(public_tweets, f)

public_tweets = api.user_timeline('Lions', count=100)

with open('Lions_Large.pkl', 'wb') as f:
   pickle.dump(public_tweets, f)
public_tweets = api.user_timeline('Saints', count=100)

with open('Saints_Large.pkl', 'wb') as f:
   pickle.dump(public_tweets, f)

public_tweets = api.user_timeline('AtlantaFalcons', count=100)

with open('Falcons_Large.pkl', 'wb') as f:
   pickle.dump(public_tweets, f)

public_tweets = api.user_timeline('Panthers', count=100)

with open('Panthers_Large.pkl', 'wb') as f:
   pickle.dump(public_tweets, f)

public_tweets = api.user_timeline('Buccaneers', count=100)

with open('Buccaneers_Large.pkl', 'wb') as f:
   pickle.dump(public_tweets, f)
public_tweets = api.user_timeline('RamsNFL', count=100)

with open('Rams_Large.pkl', 'wb') as f:
   pickle.dump(public_tweets, f)

public_tweets = api.user_timeline('Seahawks', count=100)

with open('Seahawks_Large.pkl', 'wb') as f:
   pickle.dump(public_tweets, f)

public_tweets = api.user_timeline('49ers', count=100)

with open('49ers_Large.pkl', 'wb') as f:
   pickle.dump(public_tweets, f)

public_tweets = api.user_timeline('AZCardinals', count=100)

with open('Cardinals_Large.pkl', 'wb') as f:
   pickle.dump(public_tweets, f)
